# %%
from google.colab import files
uploaded = files.upload()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('country_wise_latest.csv')
df.fillna(0, inplace=True)
print(new_df.to_string())
#Summary of Countries with Highest Deaths
summary = df.groupby('Country/Region')[['Confirmed', 'Deaths', 'Recovered']].sum()
summary = summary.sort_values(by='Confirmed', ascending=False)
print("\nGlobal Summary (Sorted by Confirmed Cases):")
print(summary)

#Bar chart of Top 10 Countries with Most Confirmed Cases
total_by_country = df.groupby('Country/Region')['Confirmed'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
total_by_country.head(10).plot(kind='bar', color='skyblue')
plt.title("Top 10 Countries with Most Confirmed Cases")
plt.xlabel("Country")
plt.ylabel("Confirmed Cases")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()


country_name = "India"
india_data = df[df['Country/Region'] == country_name]

if not india_data.empty:
    confirmed = india_data['Confirmed'].values[0]
    deaths = india_data['Deaths'].values[0]
    recovered = india_data['Recovered'].values[0]
    active = confirmed - deaths - recovered

    # Bar chart
    plt.figure(figsize=(6, 5))
    plt.bar(['Confirmed', 'Deaths', 'Recovered'], [confirmed, deaths, recovered], color=['blue', 'red', 'green'])
    plt.title(f"COVID-19 Summary in {country_name}")
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()

    # Pie chart
    plt.figure(figsize=(6, 6))
    labels = ['Deaths', 'Recovered', 'Active']
    sizes = [deaths, recovered, active]
    colors = ['red', 'green', 'orange']
    plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
    plt.title(f"COVID-19 Proportions in {country_name}")
    plt.axis('equal')
    plt.tight_layout()
    plt.show()
else:
    print(f"No data found for {country_name}")
